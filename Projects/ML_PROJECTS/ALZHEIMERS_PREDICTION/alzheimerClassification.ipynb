# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('Alzheimer.csv')

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
df.shape
# Out:
# (373, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Subject ID  373 non-null    object
#  1   MRI ID      373 non-null    object
#  2   Group       373 non-null    object
#  3   Visit       373 non-null    int64
#  4   MR Delay    373 non-null    int64
#  5   M/F         373 non-null    object
#  6   Hand        373 non-null    object
#  7   Age         373 non-null    int64
#  8   EDUC        373 non-null    int64
#  9   SES         354 non-null    float64
#  10  MMSE        371 non-null    float64
#  11  CDR         373 non-null    float64
#  12  eTIV        373 non-null    int64
#  13  nWBV        373 non-null    float64
#  14  ASF         373 non-null    float64
# dtypes: float64(5), int64(5), object(5)
# memory usage: 43.8+ KB

# %%
df.isna().sum()
# Out:
# Subject ID     0
# MRI ID         0
# Group          0
# Visit          0
# MR Delay       0
# M/F            0
# Hand           0
# Age            0
# EDUC           0
# SES           19
# MMSE           2
# CDR            0
# eTIV           0
# nWBV           0
# ASF            0
# dtype: int64

# %%
(df.isna().sum()/df.shape[0])*100
# Out:
# Subject ID    0.000000
# MRI ID        0.000000
# Group         0.000000
# Visit         0.000000
# MR Delay      0.000000
# M/F           0.000000
# Hand          0.000000
# Age           0.000000
# EDUC          0.000000
# SES           5.093834
# MMSE          0.536193
# CDR           0.000000
# eTIV          0.000000
# nWBV          0.000000
# ASF           0.000000
# dtype: float64

# %%
ses_replace , mmse_replace = df.SES.median(), df.MMSE.median()
ses_replace , mmse_replace
# Out:
# (2.0, 29.0)

# %%
df.SES.fillna(ses_replace,inplace=True)

# %%
df.MMSE.fillna(mmse_replace,inplace=True)

# %%
df.isna().sum()
# Out:
# Subject ID    0
# MRI ID        0
# Group         0
# Visit         0
# MR Delay      0
# M/F           0
# Hand          0
# Age           0
# EDUC          0
# SES           0
# MMSE          0
# CDR           0
# eTIV          0
# nWBV          0
# ASF           0
# dtype: int64

# %% [markdown]
# Null values processed

# %%
df.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  2.0  23.0  0.5  1678  0.736  1.046
# 3  2.0  28.0  0.5  1738  0.713  1.010
# 4  2.0  22.0  0.5  1698  0.701  1.034

# %%
processed_df = df[['Group','M/F','Age','EDUC','SES','MMSE','CDR','eTIV','nWBV','ASF']]

# %%
demented_df = processed_df[processed_df['Group']=='Demented']

# %%
demented_df.EDUC.value_counts()
# Out:
# EDUC
# 12    57
# 16    29
# 14    12
# 18    10
# 15    10
# 8      7
# 20     6
# 13     6
# 11     4
# 6      3
# 17     2
# Name: count, dtype: int64

# %%
processed_df.groupby('Group').count()
# Out:
#              M/F  Age  EDUC  SES  MMSE  CDR  eTIV  nWBV  ASF
# Group
# Converted     37   37    37   37    37   37    37    37   37
# Demented     146  146   146  146   146  146   146   146  146
# Nondemented  190  190   190  190   190  190   190   190  190

# %%
#processed_df['Group'] = df['Group'].apply(lambda x: 1 if x == 'Demented' else 0)

# %%
processed_df.head()
# Out:
#          Group M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  Nondemented   M   87    14  2.0  27.0  0.0  1987  0.696  0.883
# 1  Nondemented   M   88    14  2.0  30.0  0.0  2004  0.681  0.876
# 2     Demented   M   75    12  2.0  23.0  0.5  1678  0.736  1.046
# 3     Demented   M   76    12  2.0  28.0  0.5  1738  0.713  1.010
# 4     Demented   M   80    12  2.0  22.0  0.5  1698  0.701  1.034

# %%
processed_df[processed_df['Group']=='Converted'].head()
# Out:
#         Group M/F  Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# 33  Converted   F   87    14  1.0  30.0  0.0  1406  0.715  1.248
# 34  Converted   F   88    14  1.0  29.0  0.0  1398  0.713  1.255
# 35  Converted   F   92    14  1.0  27.0  0.5  1423  0.696  1.234
# 36  Converted   M   80    20  1.0  29.0  0.0  1587  0.693  1.106
# 37  Converted   M   82    20  1.0  28.0  0.5  1606  0.677  1.093

# %%
X = processed_df[['Age','EDUC','SES','MMSE','CDR','eTIV','nWBV','ASF','M/F']]
Y = processed_df[['Group']]

# %%
X.head()
# Out:
#    Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF M/F
# 0   87    14  2.0  27.0  0.0  1987  0.696  0.883   M
# 1   88    14  2.0  30.0  0.0  2004  0.681  0.876   M
# 2   75    12  2.0  23.0  0.5  1678  0.736  1.046   M
# 3   76    12  2.0  28.0  0.5  1738  0.713  1.010   M
# 4   80    12  2.0  22.0  0.5  1698  0.701  1.034   M

# %%
Y.head()
# Out:
#          Group
# 0  Nondemented
# 1  Nondemented
# 2     Demented
# 3     Demented
# 4     Demented

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder

to_scale = ['Age','EDUC','SES','MMSE','CDR','eTIV','nWBV','ASF']
to_ohe = ['M/F']

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('StandardScaler',StandardScaler(),to_scale),
        ('One-Hot Encoder',OneHotEncoder(),to_ohe)
    ])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score,classification_report

# %%
pipeline_rf = Pipeline([
    ('Preprocessor',preprocessor),
    ('RandomForest',RandomForestClassifier(random_state=42))
])
pipeline_svc = Pipeline([
    ('Preprocessor', preprocessor),
    ('SVM-C', SVC(random_state=42))
])

# %%
from sklearn.model_selection import train_test_split,GridSearchCV

X_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

# %%
param_grid_rf = {
    'RandomForest__n_estimators': [100, 150, 200, 250],
    'RandomForest__max_depth': [None, 5, 10, 20],
    'RandomForest__min_samples_split': [2, 5, 10],
    'RandomForest__min_samples_leaf': [1, 2, 4],
}

# %%
param_grid_svc = {
    'SVM-C__C': [0.1, 1, 10],
    'SVM-C__gamma': [1, 0.1, 0.01],
    'SVM-C__kernel': ['rbf', 'linear']
}

# %%
grid_search = GridSearchCV(pipeline_rf, param_grid_rf, cv=10, scoring='accuracy')
grid_search.fit(X_train, y_train)

best_model_rf = grid_search.best_estimator_
best_params_rf = grid_search.best_params_

accuracy = best_model_rf.score(x_test, y_test)
print("Accuracy:", accuracy)
print("Best hyperparameters for RF: ",best_params_rf)
# Out:
# Accuracy: 0.8533333333333334
# Best hyperparameters for RF:  {'RandomForest__max_depth': None, 'RandomForest__min_samples_leaf': 1, 'RandomForest__min_samples_split': 5, 'RandomForest__n_estimators': 250}

# %%
grid_search = GridSearchCV(pipeline_svc, param_grid_svc, cv=10, scoring='accuracy')
grid_search.fit(X_train, y_train)

best_model_svc = grid_search.best_estimator_
best_params_svc = grid_search.best_params_

accuracy = best_model_svc.score(x_test, y_test)
print("Accuracy:", accuracy)
print("Best hyperparameters for SVM-C: ",best_params_svc)
# Out:
# Accuracy: 0.8266666666666667
# Best hyperparameters for SVM-C:  {'SVM-C__C': 10, 'SVM-C__gamma': 1, 'SVM-C__kernel': 'linear'}

# %%
import pickle

# %%
with open('best_model.pkl', 'wb') as file:
    pickle.dump(best_model_rf, file)

# %%
with open('best_model.pkl', 'rb') as file:
    best_model = pickle.load(file)

# %% [markdown]
# Demented

# %%
#new_data = pd.DataFrame({'Age': [65],'EDUC': [12],'SES': [2],'MMSE': [29],'CDR': [0.5],'eTIV': [1500],'nWBV': [0.75],'ASF': [1.2],'M/F': ['M']})

# %% [markdown]
# Non Demented

# %%
#new_data = pd.DataFrame({'Age': [88],'EDUC': [14],'SES': [2.0],'MMSE': [30.0],'CDR': [0.0],'eTIV': [2004],'nWBV': [0.681],'ASF': [0.876],'M/F': ['M']})

# %% [markdown]
# Converted

# %%
new_data = pd.DataFrame({'Age': [92],'EDUC': [14],'SES': [1.0],'MMSE': [27.0],'CDR': [0.5],'eTIV': [1423],'nWBV': [0.696],'ASF': [1.234],'M/F': ['F']})

# %%
prediction = best_model.predict(new_data)[0]

# %%
print(prediction)
# Out:
# 0
